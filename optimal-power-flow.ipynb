# %%
import numpy as np
import pandapower as pp
import pandapower.networks as pn
from pandapower import runpp, runopp
import pandas as pd
import pyomo.environ as pyo
import copy

# %%
class Component: # Basic component in power system optimization model

    def __init__(self, **kwargs):
        self.baseMVA = 100
        pass

    def create_parameters(self):
        pass

    def update_timeseries_parameters(self, date):
        pass

    def create_variables(self):
        pass

    def create_expressions(self):
        pass

# %%
class Bus(Component):

    def __init__(self, name: str, data: pd.Series, load_data: pd.Series, shunt_data: pd.Series):
        super().__init__()

        self.name = name
        self.type = data["type"]
        self.vbase = data["vn_kv"]
        self.vmax = data["max_vm_pu"]
        self.vmin = data["min_vm_pu"]
        self.pD = load_data["p_mw"] / self.baseMVA
        self.qD = load_data["q_mvar"] / self.baseMVA
        self.qShunt = shunt_data["q_mvar"] / self.baseMVA
        self.slack_cost = None # Generation cost for external grid (for slack bus only)

        self.generators = []
        self.in_lines = []
        self.out_lines = []
        
    @classmethod
    def from_series(cls, data: pd.Series, load_data: pd.Series, shunt_data: pd.Series):
        return cls(data.name, data, load_data, shunt_data)

class Generator(Component):

    def __init__(self, name: str, data: pd.Series, cost_data: pd.Series):
        super().__init__()

        self.name = name
        self.bus_ID = data["bus"]
        self.pmin = data["min_p_mw"] / self.baseMVA
        self.pmax = data["max_p_mw"] / self.baseMVA
        self.qmin = data["min_q_mvar"] / self.baseMVA
        self.qmax = data["max_q_mvar"] / self.baseMVA
        self.cost = cost_data[["cp0_eur", "cp1_eur_per_mw", "cp2_eur_per_mw2"]].astype(np.float64).values.flatten()
        
        self.bus = None
        
    @classmethod
    def from_series(cls, data: pd.Series, cost_data: pd.Series):
        return cls(data.name, data, cost_data)

    def link_bus(self, buses: dict):
        # Link node to resource
        self.bus = buses[self.bus_ID]
        # Link resource to node
        buses[self.bus_ID].generators.append(self)

class Line(Component):

    def __init__(self, name: str, data: pd.Series):
        super().__init__()

        self.name = name
        self.from_bus_ID = data["from_bus"]
        self.to_bus_ID = data["to_bus"]
        # self.r_ohm = data["length_km"] * data["r_ohm_per_km"]
        # self.x_ohm = data["length_km"] * data["x_ohm_per_km"]
        # self.c_nf = data["length_km"] * data["c_nf_per_km"] # Line shunt admittance
        self.imax = data["max_i_ka"]

        # # Per unit line impedance / admittance values
        # self.z, self.r, self.x, self.y, self.g, self.b = None, None, None, None, None, None

        self.from_bus = None
        self.to_bus = None

    # def calculate_admittance(self):
    #     # Calculate base impedance (ohms)
    #     vbase = self.from_bus.vbase * 1e3 # convert kV to V
    #     sbase = self.baseMVA * 1e6 # convert MVA to VA
    #     zbase = vbase**2 / sbase

    #     assert abs(self.from_bus.vbase - self.to_bus.vbase) < 1e-3, "Voltage base mismatch across line ends."

    #     # Convert r and x to per unit
    #     self.r = self.r_ohm / zbase
    #     self.x = self.x_ohm / zbase
    #     self.z = complex(self.r, self.x) # Impedance

    #     # Calculate y, g and b
    #     self.y = 1 / self.z if abs(self.z) > 0 else 0 # Admittance
    #     self.g, self.b = np.real(self.y), np.imag(self.y)

    @classmethod
    def from_series(cls, data: pd.Series):
        return cls(data.name, data)

    def link_buses(self, buses: dict):
        # Link buses to line
        self.from_bus = buses[self.from_bus_ID]
        self.to_bus = buses[self.to_bus_ID]
        # Link line to nodes
        buses[self.from_bus_ID].out_lines.append(self)
        buses[self.to_bus_ID].in_lines.append(self)

# %%
class Model:

    def __init__(self, network, settings=None):

        # PandaPower network and model settings
        self.net = network
        self.settings = settings
        self.baseMVA = network.sn_mva
        
        # Power system components
        self.buses = {}
        self.generators = {}
        self.lines = {}

    @property
    def components(self):
        return list(self.buses.values() + self.generators.values() + self.lines.values())

    def create_system(self):

        # Run power flow
        runpp(self.net)

        # Pre-process data
        net = copy.copy(self.net)
        # Add loads to all buses
        net.load = net.load.set_index("bus").reindex(net.bus.index)
        net.load[["p_mw", "q_mvar"]] = net.load[["p_mw", "q_mvar"]].fillna(0)
        # Add shunts to all busees
        net.shunt = net.shunt.set_index("bus").reindex(net.bus.index)
        net.shunt["q_mvar"] = net.shunt["q_mvar"].fillna(0)

        # Get generator / slack bus cost data
        gen_cost = net.poly_cost.loc[net.poly_cost["et"] == "gen"].set_index("element")
        slack_cost = net.poly_cost.loc[net.poly_cost["et"] == "ext_grid"].set_index("element")
        
        # Create buses, generators, and line instances from network data
        for bus in net.bus.index:
            self.buses[bus] = Bus.from_series(net.bus.loc[bus], net.load.loc[bus], net.shunt.loc[bus])
        
        for gen in net.gen.index:
            self.generators[gen] = Generator.from_series(net.gen.loc[gen], net.poly_cost.loc[gen])
            self.generators[gen].link_bus(self.buses) # Link generator to node
            
        for line in net.line.index:
            self.lines[line] = Line.from_series(net.line.loc[line])
            self.lines[line].link_buses(self.buses) # Link line to nodes

        # Create admittance matrix
        Y_int = np.array(net._ppc["internal"]["Ybus"].todense())
        ext_to_int = net._pd2ppc_lookups["bus"]
        Y = np.zeros(Y_int.shape, dtype=np.complex128)
        for i in net.bus.index:
            for j in net.bus.index:
                Y[i,j] = Y_int[ext_to_int[i], ext_to_int[j]]
        self.Y = Y
        
        # Split real and imaginary components
        self.G = np.real(self.Y)
        self.B = np.imag(self.Y)

        # Determine slack bus
        self.slack_bus = self.buses[int(self.net.ext_grid.bus.values[0])]
        self.slack_bus.slack_cost = slack_cost[["cp0_eur", "cp1_eur_per_mw", "cp2_eur_per_mw2"]].values.flatten()

    def build_model(self):
        pass

    def solve_model(self):
        pass


class SDP_AC_OPF(Model):
    pass

# %%
class Poly_AC_OPF(Model):

    def __init__(self, network, settings=None):
        super().__init__(network, settings)

        # Pyomo Model
        self.model = None

    def build_model(self):

        # Instantiate model
        model = pyo.ConcreteModel()
        self.model = model
        
        # Create sets
        model.buses = pyo.Set(initialize=list(self.buses.keys()))
        model.generators = pyo.Set(initialize=list(self.generators.keys()))
        model.lines = pyo.Set(initialize=list(self.lines.keys()))
        model.slack = pyo.Set(initialize=[self.slack_bus.name])
        
        # Create parameters
        model.P_load = pyo.Param(model.buses, initialize={i: bus.pD for i, bus in self.buses.items()}, mutable=True)
        model.Q_load = pyo.Param(model.buses, initialize={i: bus.qD for i, bus in self.buses.items()}, mutable=True)
        
        # Create variables
        
        # Bus voltage
        model.V_re = pyo.Var(model.buses, within=pyo.Reals, initialize=1.0)
        model.V_im = pyo.Var(model.buses, within=pyo.Reals, initialize=0.0)
        
        # Generation
        model.P_gen = pyo.Var(model.generators, within=pyo.Reals, initialize=0.5)
        model.Q_gen = pyo.Var(model.generators, within=pyo.Reals, initialize=0.0)

        # External grid (slack bus) generation
        model.P_slack = pyo.Var(model.slack, within=pyo.Reals, initialize=0.5)
        model.Q_slack = pyo.Var(model.slack, within=pyo.Reals, initialize=0.0)

        # Write constraints
        
        # Power flow balance constraints
        def P_balance_rule(m, k):
            bus = self.buses[k]
            P_gen = sum(m.P_gen[g.name] for g in bus.generators)
            if k in model.slack:
                P_gen += m.P_slack[k]
            P_flow = m.V_re[k] * sum(self.G[k,i] * m.V_re[i] - self.B[k,i] * m.V_im[i] for i in m.buses) \
                   + m.V_im[k] * sum(self.B[k,i] * m.V_re[i] + self.G[k,i] * m.V_im[i] for i in m.buses)
            return P_gen == P_flow + m.P_load[k]
        model.P_balance = pyo.Constraint(model.buses, rule=P_balance_rule)
        
        def Q_balance_rule(m, k):
            bus = self.buses[k]
            Q_gen = sum(m.Q_gen[g.name] for g in bus.generators)
            if k in model.slack:
                Q_gen += m.Q_slack[k]
            Q_flow = m.V_re[k] * sum(-self.B[k,i] * m.V_re[i] - self.G[k,i] * m.V_im[i] for i in m.buses) \
                   + m.V_im[k] * sum(self.G[k,i] * m.V_re[i] - self.B[k,i] * m.V_im[i] for i in m.buses)
            return Q_gen == Q_flow + m.Q_load[k]
        model.Q_balance = pyo.Constraint(model.buses, rule=Q_balance_rule)
        
        # Voltage magnitude constraints
        def V_mag_rule(m, k):
            bus = self.buses[k]
            return pyo.inequality(bus.vmin**2, m.V_re[k]**2 + m.V_im[k]**2, bus.vmax**2)
        model.V_mag = pyo.Constraint(model.buses, rule=V_mag_rule)

        # Fix slack bus voltage and voltage angle
        for slack in model.slack:
            model.V_re[slack].fix(1.0)
            model.V_im[slack].fix(0.0)
        
        # Generator limits
        def P_gen_limits_rule(m, g):
            gen = self.generators[g]
            return pyo.inequality(gen.pmin, m.P_gen[g], gen.pmax)
        model.P_gen_limits = pyo.Constraint(model.generators, rule=P_gen_limits_rule)
        
        def Q_gen_limits_rule(m, g):
            gen = self.generators[g]
            return pyo.inequality(gen.qmin, m.Q_gen[g], gen.qmax)
        model.Q_gen_limits = pyo.Constraint(model.generators, rule=Q_gen_limits_rule)

        # Set objective
        def objective_rule(m):
            cost = sum(gen.cost[0] + gen.cost[1] * (gen.baseMVA * m.P_gen[i]) + gen.cost[2] * (gen.baseMVA * m.P_gen[i])**2 for i, gen in self.generators.items())
            slack_bus, slack_bus_ID = self.slack_bus, self.slack_bus.name
            cost += slack_bus.slack_cost[0] + slack_bus.slack_cost[1] * (slack_bus.baseMVA * m.P_slack[slack_bus_ID]) + slack_bus.slack_cost[2] * (slack_bus.baseMVA * m.P_slack[slack_bus_ID])**2
            return cost
        model.obj = pyo.Objective(rule=objective_rule, sense=pyo.minimize)

    def initialize_model(self):

        # Relax voltage constraints
        net.bus["max_vm_pu"] *= 1.03
        net.bus["min_vm_pu"] *= 0.97
        
        # Run power flow
        runopp(self.net, numba=False)
        
        # Extract complex bus voltages
        vm = self.net.res_bus.vm_pu  # per unit voltage magnitude
        va = np.deg2rad(self.net.res_bus.va_degree)  # voltage angle in degrees
        v = vm * np.exp(1j * va)
        v_re, v_im = v.map(np.real), v.map(np.imag)
        
        # Extract complex generator power injections
        pg = self.net.res_gen.p_mw
        qg = self.net.res_gen.q_mvar

        # Initialize values
        for k in self.model.buses:
            self.model.V_re[k].value = v_re.loc[k]
            self.model.V_im[k].value = v_im.loc[k]

        # Initialize values
        for g in self.model.generators:
            self.model.P_gen[g].value = pg.loc[g]
            self.model.Q_gen[g].value = qg.loc[g]

        # Fix slack bus voltage and voltage angle
        for slack in self.model.slack:
            self.model.V_re[slack].fix(1.0)
            self.model.V_im[slack].fix(0.0)
        
    def solve_model(self):
        solver = pyo.SolverFactory('ipopt')
        solver.solve(self.model, tee=True)

    def print_solution(self):
        # Display results
        print("\n=== Generator Dispatch (MW) ===")
        for gen in self.generators.values():
            print(f"Generator {gen.name} at bus {gen.bus.name}: P = {pyo.value(self.model.P_gen[gen.name]) * gen.baseMVA:.2f} MW, Q = {pyo.value(self.model.Q_gen[gen.name]) * gen.baseMVA:.2f} MVar")
        
        print("\n=== Bus Voltages (p.u.) ===")
        for bus in self.buses.values():
            V_re = pyo.value(self.model.V_re[bus.name])
            V_im = pyo.value(self.model.V_im[bus.name])
            V_mag = np.sqrt(V_re**2 + V_im**2)
            V_angle = np.degrees(np.arctan2(V_im, V_re))
            print(f"Bus {bus.name}: |V| = {V_mag:.4f} p.u., angle = {V_angle:.2f}°")

# %%
net = pn.case300()

# %%
model = Poly_AC_OPF(net) # Initialize model object
model.create_system() # Create power system component objects from pandapower case data
for bus in model.buses.values(): # Update bus voltage parameters
    bus.vmax *= 1.03
    bus.vmin *= 0.97
model.build_model() # Write Pyomo model constraints
model.initialize_model() # Initialize values (set starting point)
model.solve_model()
model.print_solution()
# Out:
# Ipopt 3.14.17:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.7.3.
#
# Number of nonzeros in equality constraint Jacobian...:     4604
# Number of nonzeros in inequality constraint Jacobian.:      735
# Number of nonzeros in Lagrangian Hessian.............:     2601
#
# Total number of variables............................:      737
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      600
# Total number of inequality constraints...............:      436
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:      436
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0223651e+10 1.95e+03 3.99e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.9018340e+09 1.71e+03 3.59e+01  -1.0 1.96e+03    -  2.10e-02 1.22e-01f  1
#    2  7.8966184e+09 1.71e+03 3.55e+01  -1.0 1.44e+03   0.0 1.10e-04 3.92e-04f  1
#    3  6.9601329e+09 1.61e+03 3.33e+01  -1.0 1.71e+03    -  5.54e-02 6.21e-02f  1
#    4  6.7499328e+09 1.58e+03 3.40e+01  -1.0 1.64e+03    -  2.80e-03 1.54e-02f  1
#    5  6.7457283e+09 1.58e+03 3.38e+01  -1.0 1.45e+03   0.4 3.45e-05 3.98e-04f  1
#    6  6.7464186e+09 1.58e+03 3.34e+01  -1.0 1.48e+04  -0.1 3.80e-06 2.87e-05h  1
#    7  6.7426329e+09 1.58e+03 3.43e+01  -1.0 1.50e+03   0.4 1.24e-03 3.38e-04f  1
#    8  6.7183442e+09 1.58e+03 3.66e+01  -1.0 1.58e+03  -0.1 4.23e-03 1.89e-03f  1
#    9  5.9226845e+09 1.48e+03 3.53e+01  -1.0 1.58e+03    -  2.28e-02 6.21e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.0764736e+09 1.37e+03 3.18e+01  -1.0 1.48e+03    -  1.60e-01 7.55e-02f  1
#   11  2.4703476e+09 9.47e+02 2.28e+01  -1.0 1.37e+03    -  1.19e-01 3.08e-01f  1
#   12  1.1019116e+09 6.24e+02 1.59e+01  -1.0 9.47e+02    -  1.90e-01 3.41e-01f  1
#   13  5.1974840e+08 4.20e+02 1.07e+01  -1.0 6.24e+02    -  3.60e-01 3.26e-01f  1
#   14  1.3798971e+08 2.05e+02 7.96e+00  -1.0 4.20e+02    -  1.91e-01 5.13e-01f  1
#   15  1.5657723e+06 2.75e-01 5.12e+00  -1.0 2.05e+02    -  3.78e-01 1.00e+00f  1
#   16  1.4236554e+06 3.90e+00 3.77e+00  -1.0 7.16e+00    -  4.40e-01 1.00e+00f  1
#   17  1.2804114e+06 2.34e+00 3.93e+00  -1.0 6.96e+00    -  2.29e-01 5.72e-01f  1
#   18  1.2800620e+06 5.58e-01 2.78e+00  -1.0 3.38e+00    -  6.97e-01 1.00e+00f  1
#   19  1.2194554e+06 9.62e-01 4.00e-01  -1.0 2.28e+00    -  5.32e-01 8.90e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.1255164e+06 4.09e+00 9.86e-01  -1.7 4.21e+00    -  7.37e-01 1.00e+00f  1
#   21  1.0907330e+06 2.20e+00 2.15e-01  -1.7 2.05e+00    -  1.00e+00 1.00e+00h  1
#   22  1.0880831e+06 1.97e-01 1.90e-02  -1.7 5.53e-01    -  1.00e+00 1.00e+00h  1
#   23  1.0626023e+06 3.62e-01 1.30e-01  -2.5 1.29e+00    -  8.57e-01 7.31e-01h  1
#   24  1.0484710e+06 2.51e-01 2.83e-01  -2.5 7.77e-01    -  1.00e+00 8.17e-01h  1
#   25  1.0449317e+06 3.37e-02 5.24e-03  -2.5 2.59e-01    -  1.00e+00 1.00e+00h  1
#   26  1.0447958e+06 1.67e-04 2.18e-04  -2.5 2.38e-02    -  1.00e+00 1.00e+00h  1
#   27  1.0388315e+06 4.61e-02 2.12e-02  -3.8 4.88e-01    -  6.85e-01 7.18e-01f  1
#   28  1.0366512e+06 2.39e-02 1.48e-02  -3.8 6.07e-01    -  6.37e-01 5.77e-01h  1
#   29  1.0353801e+06 9.16e-03 2.63e-02  -3.8 5.75e-01    -  8.26e-01 6.36e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.0347244e+06 3.50e-03 1.22e-03  -3.8 7.95e-01    -  1.00e+00 1.00e+00h  1
#   31  1.0347090e+06 4.81e-04 1.49e-05  -3.8 1.98e-01    -  1.00e+00 1.00e+00h  1
#   32  1.0341999e+06 1.91e-03 2.39e-03  -5.7 6.94e-01    -  7.83e-01 7.45e-01h  1
#   33  1.0340693e+06 1.77e-03 2.39e-02  -5.7 4.98e-01    -  9.87e-01 6.73e-01h  1
#   34  1.0340340e+06 1.13e-03 2.54e-02  -5.7 2.71e-01    -  1.00e+00 6.22e-01h  1
#   35  1.0340141e+06 3.86e-04 1.87e-05  -5.7 1.30e-01    -  1.00e+00 1.00e+00f  1
#   36  1.0340146e+06 8.06e-06 8.75e-08  -5.7 1.27e-02    -  1.00e+00 1.00e+00h  1
#   37  1.0340068e+06 4.03e-05 2.10e-04  -8.6 3.77e-02    -  9.86e-01 9.56e-01h  1
#   38  1.0340064e+06 5.07e-06 5.72e-08  -8.6 9.86e-03    -  1.00e+00 1.00e+00h  1
#   39  1.0340064e+06 1.51e-07 1.76e-09  -8.6 1.71e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.0340064e+06 2.41e-10 2.81e-12  -8.6 6.81e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 40
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.6972518697297723e+01    1.0340064370166804e+06
# Dual infeasibility......:   2.8136058431610648e-12    1.0786113769003544e-07
# Constraint violation....:   2.4069479742649946e-10    2.4069479742649946e-10
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5091448842774987e-09    9.6189458272962015e-05
# Overall NLP error.......:   2.5091448842774987e-09    9.6189458272962015e-05
#
#
# Number of objective function evaluations             = 41
# Number of objective gradient evaluations             = 41
# Number of equality constraint evaluations            = 41
# Number of inequality constraint evaluations          = 41
# Number of equality constraint Jacobian evaluations   = 41
# Number of inequality constraint Jacobian evaluations = 41
# Number of Lagrangian Hessian evaluations             = 40
# Total seconds in IPOPT                               = 0.051
#
# EXIT: Optimal Solution Found.
#
# === Generator Dispatch (MW) ===
# Generator 0 at bus 7: P = 100.00 MW, Q = 10.00 MVar
# Generator 1 at bus 9: P = 100.00 MW, Q = 20.00 MVar
# Generator 2 at bus 18: P = 100.00 MW, Q = 20.00 MVar
# Generator 3 at bus 54: P = 100.00 MW, Q = 25.00 MVar
# Generator 4 at bus 62: P = 100.00 MW, Q = 35.00 MVar
# Generator 5 at bus 68: P = 475.00 MW, Q = 183.86 MVar
# Generator 6 at bus 75: P = 255.00 MW, Q = -1.54 MVar
# Generator 7 at bus 76: P = 390.00 MW, Q = 30.49 MVar
# Generator 8 at bus 79: P = 166.51 MW, Q = -7.04 MVar
# Generator 9 at bus 87: P = 217.00 MW, Q = 61.54 MVar
# Generator 10 at bus 97: P = 1210.14 MW, Q = 1154.92 MVar
# Generator 11 at bus 102: P = 340.00 MW, Q = 91.52 MVar
# Generator 12 at bus 103: P = 100.00 MW, Q = 200.00 MVar
# Generator 13 at bus 116: P = 100.00 MW, Q = 350.00 MVar
# Generator 14 at bus 119: P = 381.00 MW, Q = 75.00 MVar
# Generator 15 at bus 121: P = 461.91 MW, Q = 271.72 MVar
# Generator 16 at bus 124: P = 184.00 MW, Q = 35.00 MVar
# Generator 17 at bus 125: P = 317.00 MW, Q = -21.66 MVar
# Generator 18 at bus 127: P = 183.95 MW, Q = 7.49 MVar
# Generator 19 at bus 130: P = 424.70 MW, Q = 28.63 MVar
# Generator 20 at bus 131: P = 316.00 MW, Q = -17.51 MVar
# Generator 21 at bus 134: P = 100.00 MW, Q = 15.00 MVar
# Generator 22 at bus 148: P = 305.00 MW, Q = 90.00 MVar
# Generator 23 at bus 149: P = 100.00 MW, Q = 150.00 MVar
# Generator 24 at bus 154: P = 328.00 MW, Q = 54.55 MVar
# Generator 25 at bus 155: P = 184.00 MW, Q = 35.00 MVar
# Generator 26 at bus 163: P = 300.00 MW, Q = 80.00 MVar
# Generator 27 at bus 164: P = 284.25 MW, Q = 346.20 MVar
# Generator 28 at bus 165: P = 1265.17 MW, Q = 343.83 MVar
# Generator 29 at bus 168: P = 575.00 MW, Q = -60.00 MVar
# Generator 30 at bus 169: P = 1007.30 MW, Q = 491.66 MVar
# Generator 31 at bus 176: P = 524.00 MW, Q = 152.67 MVar
# Generator 32 at bus 191: P = 372.00 MW, Q = 89.25 MVar
# Generator 33 at bus 198: P = 200.00 MW, Q = 60.00 MVar
# Generator 34 at bus 199: P = 550.00 MW, Q = 320.00 MVar
# Generator 35 at bus 200: P = 350.00 MW, Q = 144.96 MVar
# Generator 36 at bus 205: P = 403.00 MW, Q = 300.00 MVar
# Generator 37 at bus 208: P = 445.00 MW, Q = 104.38 MVar
# Generator 38 at bus 211: P = 400.00 MW, Q = 232.57 MVar
# Generator 39 at bus 214: P = 205.06 MW, Q = 214.45 MVar
# Generator 40 at bus 216: P = 350.00 MW, Q = 200.00 MVar
# Generator 41 at bus 217: P = 650.00 MW, Q = 236.09 MVar
# Generator 42 at bus 219: P = 675.43 MW, Q = -112.99 MVar
# Generator 43 at bus 220: P = 270.00 MW, Q = 100.00 MVar
# Generator 44 at bus 221: P = 184.00 MW, Q = 51.39 MVar
# Generator 45 at bus 246: P = 567.00 MW, Q = 138.35 MVar
# Generator 46 at bus 247: P = 667.58 MW, Q = 107.98 MVar
# Generator 47 at bus 248: P = 394.98 MW, Q = 420.00 MVar
# Generator 48 at bus 249: P = 334.00 MW, Q = 100.00 MVar
# Generator 49 at bus 250: P = 472.00 MW, Q = 200.82 MVar
# Generator 50 at bus 251: P = 114.23 MW, Q = 315.60 MVar
# Generator 51 at bus 252: P = 285.00 MW, Q = 0.00 MVar
# Generator 52 at bus 253: P = 95.35 MW, Q = 51.20 MVar
# Generator 53 at bus 254: P = 360.93 MW, Q = 29.53 MVar
# Generator 54 at bus 255: P = 137.00 MW, Q = 23.31 MVar
# Generator 55 at bus 257: P = 145.00 MW, Q = 25.00 MVar
# Generator 56 at bus 258: P = 265.00 MW, Q = 41.53 MVar
# Generator 57 at bus 259: P = 247.83 MW, Q = 150.00 MVar
# Generator 58 at bus 260: P = 500.00 MW, Q = 83.88 MVar
# Generator 59 at bus 261: P = 216.00 MW, Q = 57.42 MVar
# Generator 60 at bus 262: P = 1142.25 MW, Q = 404.67 MVar
# Generator 61 at bus 263: P = 800.00 MW, Q = 325.00 MVar
# Generator 62 at bus 264: P = 653.00 MW, Q = 222.66 MVar
# Generator 63 at bus 266: P = 65.09 MW, Q = 2.00 MVar
# Generator 64 at bus 291: P = 94.49 MW, Q = 17.35 MVar
# Generator 65 at bus 293: P = 16.80 MW, Q = 12.83 MVar
# Generator 66 at bus 294: P = 150.00 MW, Q = 38.00 MVar
# Generator 67 at bus 295: P = 51.90 MW, Q = 6.00 MVar
#
# === Bus Voltages (p.u.) ===
# Bus 0: |V| = 1.0719 p.u., angle = -17.26°
# Bus 1: |V| = 1.0749 p.u., angle = -15.41°
# Bus 2: |V| = 1.0398 p.u., angle = -18.68°
# Bus 3: |V| = 1.0156 p.u., angle = -19.12°
# Bus 4: |V| = 1.0633 p.u., angle = -18.48°
# Bus 5: |V| = 1.0707 p.u., angle = -16.47°
# Bus 6: |V| = 1.0343 p.u., angle = -18.75°
# Bus 7: |V| = 1.0538 p.u., angle = -18.60°
# Bus 8: |V| = 1.0540 p.u., angle = -19.19°
# Bus 9: |V| = 1.0727 p.u., angle = -19.46°
# Bus 10: |V| = 1.0613 p.u., angle = -18.64°
# Bus 11: |V| = 1.0432 p.u., angle = -18.51°
# Bus 12: |V| = 1.0527 p.u., angle = -21.96°
# Bus 13: |V| = 1.0089 p.u., angle = -24.59°
# Bus 14: |V| = 1.0117 p.u., angle = -27.43°
# Bus 15: |V| = 1.0259 p.u., angle = -20.96°
# Bus 16: |V| = 0.9836 p.u., angle = -35.97°
# Bus 17: |V| = 1.0366 p.u., angle = -20.78°
# Bus 18: |V| = 1.0563 p.u., angle = -24.29°
# Bus 19: |V| = 1.0268 p.u., angle = -21.45°
# Bus 20: |V| = 1.0497 p.u., angle = -24.05°
# Bus 21: |V| = 1.0918 p.u., angle = -19.29°
# Bus 22: |V| = 1.0475 p.u., angle = -20.96°
# Bus 23: |V| = 1.0683 p.u., angle = -21.52°
# Bus 24: |V| = 1.0480 p.u., angle = -24.30°
# Bus 25: |V| = 1.0288 p.u., angle = -26.90°
# Bus 26: |V| = 1.0221 p.u., angle = -18.88°
# Bus 27: |V| = 1.0447 p.u., angle = -19.21°
# Bus 28: |V| = 1.0249 p.u., angle = -28.40°
# Bus 29: |V| = 1.0459 p.u., angle = -28.11°
# Bus 30: |V| = 1.0226 p.u., angle = -15.46°
# Bus 31: |V| = 1.0185 p.u., angle = -18.93°
# Bus 32: |V| = 1.0502 p.u., angle = -18.07°
# Bus 33: |V| = 1.0233 p.u., angle = -18.58°
# Bus 34: |V| = 1.0237 p.u., angle = -17.47°
# Bus 35: |V| = 1.0473 p.u., angle = -19.26°
# Bus 36: |V| = 1.0059 p.u., angle = -21.98°
# Bus 37: |V| = 1.0149 p.u., angle = -23.11°
# Bus 38: |V| = 1.0375 p.u., angle = -22.29°
# Bus 39: |V| = 1.0506 p.u., angle = -21.76°
# Bus 40: |V| = 1.0015 p.u., angle = -27.78°
# Bus 41: |V| = 1.0315 p.u., angle = -19.85°
# Bus 42: |V| = 1.0802 p.u., angle = -4.01°
# Bus 43: |V| = 1.0342 p.u., angle = -11.43°
# Bus 44: |V| = 1.0017 p.u., angle = -13.03°
# Bus 45: |V| = 0.9993 p.u., angle = -22.24°
# Bus 46: |V| = 1.0053 p.u., angle = -19.85°
# Bus 47: |V| = 1.0138 p.u., angle = -11.83°
# Bus 48: |V| = 1.0253 p.u., angle = -8.31°
# Bus 49: |V| = 0.9804 p.u., angle = -12.89°
# Bus 50: |V| = 0.9741 p.u., angle = -14.21°
# Bus 51: |V| = 1.0381 p.u., angle = -17.48°
# Bus 52: |V| = 0.9918 p.u., angle = -13.30°
# Bus 53: |V| = 1.0233 p.u., angle = -9.57°
# Bus 54: |V| = 0.9821 p.u., angle = -17.16°
# Bus 55: |V| = 1.0025 p.u., angle = -15.05°
# Bus 56: |V| = 1.0168 p.u., angle = -29.90°
# Bus 57: |V| = 0.9920 p.u., angle = -33.74°
# Bus 58: |V| = 1.0180 p.u., angle = -28.86°
# Bus 59: |V| = 1.0186 p.u., angle = -29.19°
# Bus 60: |V| = 1.0161 p.u., angle = -29.39°
# Bus 61: |V| = 1.0341 p.u., angle = -27.74°
# Bus 62: |V| = 1.0162 p.u., angle = -28.72°
# Bus 63: |V| = 1.0380 p.u., angle = -27.36°
# Bus 64: |V| = 1.0455 p.u., angle = -26.43°
# Bus 65: |V| = 1.0334 p.u., angle = -27.87°
# Bus 66: |V| = 1.0429 p.u., angle = -28.11°
# Bus 67: |V| = 1.0681 p.u., angle = -27.97°
# Bus 68: |V| = 1.0918 p.u., angle = -18.49°
# Bus 69: |V| = 1.0821 p.u., angle = -21.22°
# Bus 70: |V| = 1.0838 p.u., angle = -19.91°
# Bus 71: |V| = 1.0652 p.u., angle = -20.28°
# Bus 72: |V| = 1.0518 p.u., angle = -28.00°
# Bus 73: |V| = 1.0421 p.u., angle = -18.52°
# Bus 74: |V| = 1.0336 p.u., angle = -16.69°
# Bus 75: |V| = 1.0918 p.u., angle = -13.15°
# Bus 76: |V| = 1.0918 p.u., angle = -7.36°
# Bus 77: |V| = 1.0478 p.u., angle = -20.10°
# Bus 78: |V| = 1.0827 p.u., angle = -16.55°
# Bus 79: |V| = 1.0918 p.u., angle = -15.68°
# Bus 80: |V| = 1.0802 p.u., angle = -22.19°
# Bus 81: |V| = 1.0838 p.u., angle = -17.25°
# Bus 82: |V| = 1.0793 p.u., angle = -18.69°
# Bus 83: |V| = 1.0795 p.u., angle = -14.12°
# Bus 84: |V| = 1.0806 p.u., angle = -20.20°
# Bus 85: |V| = 1.0695 p.u., angle = -14.92°
# Bus 86: |V| = 1.0591 p.u., angle = -18.81°
# Bus 87: |V| = 1.0840 p.u., angle = -22.05°
# Bus 88: |V| = 1.0275 p.u., angle = -28.81°
# Bus 89: |V| = 1.0340 p.u., angle = -26.91°
# Bus 90: |V| = 0.9929 p.u., angle = -32.42°
# Bus 91: |V| = 1.0030 p.u., angle = -29.35°
# Bus 92: |V| = 0.9908 p.u., angle = -32.51°
# Bus 93: |V| = 0.9188 p.u., angle = -70.49°
# Bus 94: |V| = 0.9650 p.u., angle = -66.29°
# Bus 95: |V| = 0.9142 p.u., angle = -63.62°
# Bus 96: |V| = 0.9118 p.u., angle = -63.59°
# Bus 97: |V| = 1.0592 p.u., angle = -61.34°
# Bus 98: |V| = 0.9670 p.u., angle = -73.05°
# Bus 99: |V| = 0.9729 p.u., angle = -72.94°
# Bus 100: |V| = 0.9194 p.u., angle = -68.69°
# Bus 101: |V| = 0.9331 p.u., angle = -66.76°
# Bus 102: |V| = 0.9618 p.u., angle = -65.16°
# Bus 103: |V| = 0.9329 p.u., angle = -60.15°
# Bus 104: |V| = 0.9118 p.u., angle = -53.25°
# Bus 105: |V| = 0.9523 p.u., angle = -42.82°
# Bus 106: |V| = 0.9907 p.u., angle = -34.37°
# Bus 107: |V| = 0.9851 p.u., angle = -34.50°
# Bus 108: |V| = 1.0401 p.u., angle = -21.94°
# Bus 109: |V| = 1.0195 p.u., angle = -19.54°
# Bus 110: |V| = 1.0095 p.u., angle = -24.68°
# Bus 111: |V| = 0.9980 p.u., angle = -34.90°
# Bus 112: |V| = 0.9939 p.u., angle = -36.98°
# Bus 113: |V| = 1.0010 p.u., angle = -34.61°
# Bus 114: |V| = 1.0588 p.u., angle = -24.20°
# Bus 115: |V| = 1.0677 p.u., angle = -30.56°
# Bus 116: |V| = 1.0917 p.u., angle = -35.04°
# Bus 117: |V| = 1.0344 p.u., angle = -27.75°
# Bus 118: |V| = 1.0626 p.u., angle = -29.09°
# Bus 119: |V| = 1.0755 p.u., angle = -19.65°
# Bus 120: |V| = 1.0433 p.u., angle = -21.26°
# Bus 121: |V| = 1.0849 p.u., angle = -12.97°
# Bus 122: |V| = 1.0246 p.u., angle = -9.85°
# Bus 123: |V| = 1.0387 p.u., angle = -15.38°
# Bus 124: |V| = 1.0838 p.u., angle = -10.69°
# Bus 125: |V| = 1.0918 p.u., angle = -6.16°
# Bus 126: |V| = 1.0918 p.u., angle = -15.89°
# Bus 127: |V| = 1.0918 p.u., angle = -8.82°
# Bus 128: |V| = 1.0204 p.u., angle = -19.64°
# Bus 129: |V| = 1.0247 p.u., angle = -22.98°
# Bus 130: |V| = 1.0918 p.u., angle = -14.17°
# Bus 131: |V| = 1.0918 p.u., angle = -8.60°
# Bus 132: |V| = 1.0158 p.u., angle = -19.32°
# Bus 133: |V| = 1.0591 p.u., angle = -12.17°
# Bus 134: |V| = 1.0047 p.u., angle = -12.24°
# Bus 135: |V| = 0.9228 p.u., angle = -64.54°
# Bus 136: |V| = 0.9251 p.u., angle = -61.19°
# Bus 137: |V| = 0.9335 p.u., angle = -63.82°
# Bus 138: |V| = 0.9322 p.u., angle = -63.41°
# Bus 139: |V| = 1.0825 p.u., angle = -10.14°
# Bus 140: |V| = 1.0393 p.u., angle = -0.83°
# Bus 141: |V| = 1.0549 p.u., angle = -22.57°
# Bus 142: |V| = 1.0176 p.u., angle = -10.67°
# Bus 143: |V| = 1.0607 p.u., angle = 7.42°
# Bus 144: |V| = 1.0644 p.u., angle = 11.50°
# Bus 145: |V| = 0.9591 p.u., angle = -36.64°
# Bus 146: |V| = 0.9907 p.u., angle = -34.40°
# Bus 147: |V| = 0.9705 p.u., angle = -36.95°
# Bus 148: |V| = 0.9428 p.u., angle = -25.98°
# Bus 149: |V| = 0.9798 p.u., angle = -38.81°
# Bus 150: |V| = 1.0490 p.u., angle = -26.97°
# Bus 151: |V| = 0.9990 p.u., angle = -29.20°
# Bus 152: |V| = 1.0865 p.u., angle = -22.21°
# Bus 153: |V| = 0.9938 p.u., angle = -23.94°
# Bus 154: |V| = 1.0918 p.u., angle = -3.10°
# Bus 155: |V| = 1.0445 p.u., angle = -7.41°
# Bus 156: |V| = 0.9688 p.u., angle = -19.62°
# Bus 157: |V| = 0.9934 p.u., angle = -23.94°
# Bus 158: |V| = 1.0089 p.u., angle = -17.50°
# Bus 159: |V| = 1.0759 p.u., angle = -30.49°
# Bus 160: |V| = 1.0667 p.u., angle = -29.25°
# Bus 161: |V| = 1.0178 p.u., angle = -11.57°
# Bus 162: |V| = 1.0255 p.u., angle = -33.69°
# Bus 163: |V| = 1.0511 p.u., angle = -29.90°
# Bus 164: |V| = 1.0918 p.u., angle = -29.97°
# Bus 165: |V| = 1.0918 p.u., angle = -28.05°
# Bus 166: |V| = 1.0779 p.u., angle = -30.49°
# Bus 167: |V| = 1.0136 p.u., angle = -29.43°
# Bus 168: |V| = 1.0697 p.u., angle = -32.80°
# Bus 169: |V| = 1.0918 p.u., angle = -65.00°
# Bus 170: |V| = 0.9854 p.u., angle = -73.31°
# Bus 171: |V| = 1.0019 p.u., angle = -31.07°
# Bus 172: |V| = 1.0848 p.u., angle = -30.77°
# Bus 173: |V| = 1.0693 p.u., angle = -29.84°
# Bus 174: |V| = 1.0457 p.u., angle = -27.91°
# Bus 175: |V| = 1.0606 p.u., angle = -27.10°
# Bus 176: |V| = 1.0918 p.u., angle = -23.76°
# Bus 177: |V| = 1.0278 p.u., angle = -28.17°
# Bus 178: |V| = 1.0281 p.u., angle = -27.69°
# Bus 179: |V| = 0.9702 p.u., angle = -32.56°
# Bus 180: |V| = 1.0320 p.u., angle = -29.21°
# Bus 181: |V| = 1.0711 p.u., angle = -25.96°
# Bus 182: |V| = 0.9613 p.u., angle = -32.90°
# Bus 183: |V| = 0.9847 p.u., angle = -32.04°
# Bus 184: |V| = 1.0004 p.u., angle = -32.75°
# Bus 185: |V| = 1.0117 p.u., angle = -32.88°
# Bus 186: |V| = 1.0063 p.u., angle = -30.58°
# Bus 187: |V| = 1.0178 p.u., angle = -29.01°
# Bus 188: |V| = 1.0535 p.u., angle = -26.85°
# Bus 189: |V| = 1.0583 p.u., angle = -27.71°
# Bus 190: |V| = 1.0614 p.u., angle = -27.82°
# Bus 191: |V| = 1.0918 p.u., angle = -11.82°
# Bus 192: |V| = 1.0599 p.u., angle = -18.72°
# Bus 193: |V| = 1.0435 p.u., angle = -23.58°
# Bus 194: |V| = 1.0210 p.u., angle = -28.34°
# Bus 195: |V| = 1.0616 p.u., angle = -33.30°
# Bus 196: |V| = 1.0735 p.u., angle = -34.45°
# Bus 197: |V| = 1.0739 p.u., angle = -33.02°
# Bus 198: |V| = 1.0742 p.u., angle = -34.60°
# Bus 199: |V| = 1.0644 p.u., angle = -39.73°
# Bus 200: |V| = 1.0407 p.u., angle = -32.60°
# Bus 201: |V| = 1.0582 p.u., angle = -40.16°
# Bus 202: |V| = 1.0304 p.u., angle = -43.11°
# Bus 203: |V| = 0.9865 p.u., angle = -70.72°
# Bus 204: |V| = 1.0479 p.u., angle = -40.44°
# Bus 205: |V| = 1.0284 p.u., angle = -36.75°
# Bus 206: |V| = 1.0765 p.u., angle = -33.67°
# Bus 207: |V| = 1.0858 p.u., angle = -32.31°
# Bus 208: |V| = 1.0918 p.u., angle = -25.05°
# Bus 209: |V| = 1.0676 p.u., angle = -33.45°
# Bus 210: |V| = 1.0534 p.u., angle = -35.03°
# Bus 211: |V| = 1.0627 p.u., angle = -35.14°
# Bus 212: |V| = 1.0750 p.u., angle = -35.25°
# Bus 213: |V| = 1.0782 p.u., angle = -33.87°
# Bus 214: |V| = 1.0382 p.u., angle = -33.51°
# Bus 215: |V| = 1.0707 p.u., angle = -33.23°
# Bus 216: |V| = 1.0796 p.u., angle = -33.77°
# Bus 217: |V| = 1.0918 p.u., angle = -28.67°
# Bus 218: |V| = 1.0303 p.u., angle = -32.80°
# Bus 219: |V| = 1.0528 p.u., angle = -27.91°
# Bus 220: |V| = 1.0665 p.u., angle = -17.85°
# Bus 221: |V| = 1.0918 p.u., angle = -13.55°
# Bus 222: |V| = 1.0697 p.u., angle = -15.41°
# Bus 223: |V| = 1.0444 p.u., angle = -18.61°
# Bus 224: |V| = 1.0380 p.u., angle = -18.44°
# Bus 225: |V| = 1.0383 p.u., angle = -20.81°
# Bus 226: |V| = 1.0268 p.u., angle = -26.00°
# Bus 227: |V| = 1.0024 p.u., angle = -27.35°
# Bus 228: |V| = 1.0024 p.u., angle = -27.35°
# Bus 229: |V| = 1.0303 p.u., angle = -32.80°
# Bus 230: |V| = 1.0572 p.u., angle = -25.15°
# Bus 231: |V| = 1.0633 p.u., angle = -24.75°
# Bus 232: |V| = 1.0851 p.u., angle = -20.45°
# Bus 233: |V| = 1.0862 p.u., angle = -19.93°
# Bus 234: |V| = 1.0710 p.u., angle = -24.68°
# Bus 235: |V| = 0.9692 p.u., angle = -32.98°
# Bus 236: |V| = 1.0124 p.u., angle = -35.97°
# Bus 237: |V| = 1.0099 p.u., angle = -30.66°
# Bus 238: |V| = 1.0420 p.u., angle = -27.43°
# Bus 239: |V| = 1.0196 p.u., angle = -33.31°
# Bus 240: |V| = 1.0144 p.u., angle = -30.81°
# Bus 241: |V| = 1.0918 p.u., angle = -30.79°
# Bus 242: |V| = 1.0284 p.u., angle = -62.56°
# Bus 243: |V| = 1.0416 p.u., angle = -73.05°
# Bus 244: |V| = 1.0918 p.u., angle = -84.94°
# Bus 245: |V| = 1.0430 p.u., angle = -28.32°
# Bus 246: |V| = 1.0918 p.u., angle = -11.83°
# Bus 247: |V| = 1.0918 p.u., angle = -10.70°
# Bus 248: |V| = 1.0801 p.u., angle = -16.56°
# Bus 249: |V| = 1.0774 p.u., angle = -15.42°
# Bus 250: |V| = 1.0918 p.u., angle = -11.08°
# Bus 251: |V| = 1.0918 p.u., angle = -35.02°
# Bus 252: |V| = 1.0901 p.u., angle = -16.13°
# Bus 253: |V| = 1.0611 p.u., angle = -19.54°
# Bus 254: |V| = 1.0918 p.u., angle = -12.56°
# Bus 255: |V| = 1.0918 p.u., angle = -10.88°
# Bus 256: |V| = 1.0918 p.u., angle = 0.00°
# Bus 257: |V| = 1.0891 p.u., angle = 2.21°
# Bus 258: |V| = 1.0918 p.u., angle = -1.41°
# Bus 259: |V| = 1.0249 p.u., angle = -9.98°
# Bus 260: |V| = 1.0918 p.u., angle = -1.71°
# Bus 261: |V| = 1.0918 p.u., angle = -21.50°
# Bus 262: |V| = 1.0918 p.u., angle = -10.75°
# Bus 263: |V| = 1.0773 p.u., angle = -20.87°
# Bus 264: |V| = 1.0918 p.u., angle = 16.46°
# Bus 265: |V| = 1.0141 p.u., angle = -15.39°
# Bus 266: |V| = 0.9467 p.u., angle = 10.55°
# Bus 267: |V| = 0.9861 p.u., angle = -23.79°
# Bus 268: |V| = 0.9797 p.u., angle = -23.93°
# Bus 269: |V| = 1.0147 p.u., angle = -14.95°
# Bus 270: |V| = 1.0056 p.u., angle = -21.54°
# Bus 271: |V| = 0.9941 p.u., angle = -22.80°
# Bus 272: |V| = 0.9360 p.u., angle = 3.21°
# Bus 273: |V| = 0.9406 p.u., angle = 10.31°
# Bus 274: |V| = 0.9154 p.u., angle = 7.47°
# Bus 275: |V| = 0.9258 p.u., angle = 9.97°
# Bus 276: |V| = 0.9213 p.u., angle = 7.73°
# Bus 277: |V| = 0.9154 p.u., angle = 8.80°
# Bus 278: |V| = 0.9163 p.u., angle = 8.90°
# Bus 279: |V| = 0.9347 p.u., angle = -29.10°
# Bus 280: |V| = 0.9470 p.u., angle = -27.92°
# Bus 281: |V| = 0.9318 p.u., angle = -29.42°
# Bus 282: |V| = 1.0001 p.u., angle = -25.20°
# Bus 283: |V| = 0.9533 p.u., angle = -27.27°
# Bus 284: |V| = 0.9626 p.u., angle = -26.76°
# Bus 285: |V| = 0.9599 p.u., angle = -26.68°
# Bus 286: |V| = 0.9421 p.u., angle = -28.50°
# Bus 287: |V| = 0.9664 p.u., angle = -25.42°
# Bus 288: |V| = 0.9532 p.u., angle = -26.58°
# Bus 289: |V| = 0.9675 p.u., angle = -25.52°
# Bus 290: |V| = 0.9818 p.u., angle = -23.89°
# Bus 291: |V| = 1.0216 p.u., angle = -2.32°
# Bus 292: |V| = 0.9822 p.u., angle = -20.84°
# Bus 293: |V| = 1.0162 p.u., angle = -17.49°
# Bus 294: |V| = 1.0030 p.u., angle = -1.44°
# Bus 295: |V| = 0.9118 p.u., angle = 12.97°
# Bus 296: |V| = 0.9782 p.u., angle = -24.57°
# Bus 297: |V| = 0.9833 p.u., angle = -24.02°
# Bus 298: |V| = 0.9118 p.u., angle = 0.88°
# Bus 299: |V| = 1.0574 p.u., angle = -17.99°

# %%
net.gen["vm_pu"].max()
# Out:
# 1.0735

# %%
net.bus["max_vm_pu"]
# Out:
# 0      1.06
# 1      1.06
# 2      1.06
# 3      1.06
# 4      1.06
#        ...
# 295    1.06
# 296    1.06
# 297    1.06
# 298    1.06
# 299    1.06
# Name: max_vm_pu, Length: 300, dtype: float64

# %%
net = pn.case300()
net.gen["vm_pu"] = 1.0
#net.bus["max_vm_pu"] *= 1.03
#net.bus["min_vm_pu"] *= 0.97
runopp(net, numba=False)
# Out:
# ---------------------------------------------------------------------------
# OPFNotConverged                           Traceback (most recent call last)
# Cell In[259], line 5
#       2 net.gen["vm_pu"] = 1.0
#       3 #net.bus["max_vm_pu"] *= 1.03
#       4 #net.bus["min_vm_pu"] *= 0.97
# ----> 5 runopp(net, numba=False)
#
# File /opt/anaconda3/envs/icnn4opt/lib/python3.11/site-packages/pandapower/run.py:482, in runopp(net, verbose, calculate_voltage_angles, check_connectivity, suppress_warnings, switch_rx_ratio, delta, init, numba, trafo3w_losses, consider_line_temperature, **kwargs)
#     480 _check_bus_index_and_print_warning_if_high(net)
#     481 _check_gen_index_and_print_warning_if_high(net)
# --> 482 _optimal_powerflow(net, verbose, suppress_warnings, **kwargs)
#
# File /opt/anaconda3/envs/icnn4opt/lib/python3.11/site-packages/pandapower/optimal_powerflow.py:76, in _optimal_powerflow(net, verbose, suppress_warnings, **kwargs)
#      71     printpf(baseMVA=result["baseMVA"], bus=result["bus"], gen=result["gen"],
#      72             branch=result["branch"],  f=result["f"],  success=result["success"],
#      73             et=result["et"], fd=stdout, ppopt=ppopt)
#      75 if not result["success"]:
# ---> 76     raise OPFNotConverged("Optimal Power Flow did not converge!")
#      78 # ppci doesn't contain out of service elements, but ppc does -> copy results accordingly
#      79 mode = net["_options"]["mode"]
#
# OPFNotConverged: Optimal Power Flow did not converge!

# %%
# Display results
print("\n=== Generator Dispatch (MW) ===")
for gen in net.res_gen.index:
    print(f"Generator {gen} at bus {net.gen.loc[gen, 'bus']}: P = {net.res_gen.loc[gen, 'p_mw']:.2f} MW, Q = {net.res_gen.loc[gen, 'p_mw']:.2f} MVar")

print("\n=== Bus Voltages (p.u.) ===")
for bus in net.res_bus.index:
    V_mag = net.res_bus.loc[bus, "vm_pu"]
    V_angle = net.res_bus.loc[bus, "va_degree"]
    print(f"Bus {bus}: |V| = {V_mag:.4f} p.u., angle = {V_angle:.2f}°")
# Out:
# === Generator Dispatch (MW) ===
# Generator 0 at bus 7: P = 0.00 MW, Q = 0.00 MVar
# Generator 1 at bus 9: P = 0.00 MW, Q = 0.00 MVar
# Generator 2 at bus 18: P = 0.00 MW, Q = 0.00 MVar
# Generator 3 at bus 54: P = 68.36 MW, Q = 68.36 MVar
# Generator 4 at bus 62: P = 100.00 MW, Q = 100.00 MVar
# Generator 5 at bus 68: P = 403.20 MW, Q = 403.20 MVar
# Generator 6 at bus 75: P = 153.53 MW, Q = 153.53 MVar
# Generator 7 at bus 76: P = 281.74 MW, Q = 281.74 MVar
# Generator 8 at bus 79: P = 75.14 MW, Q = 75.14 MVar
# Generator 9 at bus 87: P = 140.82 MW, Q = 140.82 MVar
# Generator 10 at bus 97: P = 1973.25 MW, Q = 1973.25 MVar
# Generator 11 at bus 102: P = 248.28 MW, Q = 248.28 MVar
# Generator 12 at bus 103: P = 90.54 MW, Q = 90.54 MVar
# Generator 13 at bus 116: P = 0.00 MW, Q = 0.00 MVar
# Generator 14 at bus 119: P = 275.59 MW, Q = 275.59 MVar
# Generator 15 at bus 121: P = 653.06 MW, Q = 653.06 MVar
# Generator 16 at bus 124: P = 79.51 MW, Q = 79.51 MVar
# Generator 17 at bus 125: P = 197.90 MW, Q = 197.90 MVar
# Generator 18 at bus 127: P = 95.81 MW, Q = 95.81 MVar
# Generator 19 at bus 130: P = 340.05 MW, Q = 340.05 MVar
# Generator 20 at bus 131: P = 198.90 MW, Q = 198.90 MVar
# Generator 21 at bus 134: P = 0.00 MW, Q = 0.00 MVar
# Generator 22 at bus 148: P = 197.12 MW, Q = 197.12 MVar
# Generator 23 at bus 149: P = 35.52 MW, Q = 35.52 MVar
# Generator 24 at bus 154: P = 195.80 MW, Q = 195.80 MVar
# Generator 25 at bus 155: P = 79.14 MW, Q = 79.14 MVar
# Generator 26 at bus 163: P = 201.52 MW, Q = 201.52 MVar
# Generator 27 at bus 164: P = 1168.35 MW, Q = 1168.35 MVar
# Generator 28 at bus 165: P = 1172.32 MW, Q = 1172.32 MVar
# Generator 29 at bus 168: P = 506.08 MW, Q = 506.08 MVar
# Generator 30 at bus 169: P = 1874.29 MW, Q = 1874.29 MVar
# Generator 31 at bus 176: P = 440.29 MW, Q = 440.29 MVar
# Generator 32 at bus 191: P = 275.19 MW, Q = 275.19 MVar
# Generator 33 at bus 198: P = 107.81 MW, Q = 107.81 MVar
# Generator 34 at bus 199: P = 485.70 MW, Q = 485.70 MVar
# Generator 35 at bus 200: P = 268.81 MW, Q = 268.81 MVar
# Generator 36 at bus 205: P = 327.48 MW, Q = 327.48 MVar
# Generator 37 at bus 208: P = 360.58 MW, Q = 360.58 MVar
# Generator 38 at bus 211: P = 324.69 MW, Q = 324.69 MVar
# Generator 39 at bus 214: P = 633.51 MW, Q = 633.51 MVar
# Generator 40 at bus 216: P = 265.19 MW, Q = 265.19 MVar
# Generator 41 at bus 217: P = 577.70 MW, Q = 577.70 MVar
# Generator 42 at bus 219: P = 610.97 MW, Q = 610.97 MVar
# Generator 43 at bus 220: P = 176.09 MW, Q = 176.09 MVar
# Generator 44 at bus 221: P = 85.63 MW, Q = 85.63 MVar
# Generator 45 at bus 246: P = 428.08 MW, Q = 428.08 MVar
# Generator 46 at bus 247: P = 547.80 MW, Q = 547.80 MVar
# Generator 47 at bus 248: P = 1110.18 MW, Q = 1110.18 MVar
# Generator 48 at bus 249: P = 221.51 MW, Q = 221.51 MVar
# Generator 49 at bus 250: P = 348.71 MW, Q = 348.71 MVar
# Generator 50 at bus 251: P = 374.02 MW, Q = 374.02 MVar
# Generator 51 at bus 252: P = 163.64 MW, Q = 163.64 MVar
# Generator 52 at bus 253: P = 378.13 MW, Q = 378.13 MVar
# Generator 53 at bus 254: P = 501.88 MW, Q = 501.88 MVar
# Generator 54 at bus 255: P = 49.60 MW, Q = 49.60 MVar
# Generator 55 at bus 257: P = 49.55 MW, Q = 49.55 MVar
# Generator 56 at bus 258: P = 155.14 MW, Q = 155.14 MVar
# Generator 57 at bus 259: P = 370.42 MW, Q = 370.42 MVar
# Generator 58 at bus 260: P = 378.31 MW, Q = 378.31 MVar
# Generator 59 at bus 261: P = 136.81 MW, Q = 136.81 MVar
# Generator 60 at bus 262: P = 1198.71 MW, Q = 1198.71 MVar
# Generator 61 at bus 263: P = 710.20 MW, Q = 710.20 MVar
# Generator 62 at bus 264: P = 492.76 MW, Q = 492.76 MVar
# Generator 63 at bus 266: P = 27.87 MW, Q = 27.87 MVar
# Generator 64 at bus 291: P = 61.54 MW, Q = 61.54 MVar
# Generator 65 at bus 293: P = 53.45 MW, Q = 53.45 MVar
# Generator 66 at bus 294: P = 54.88 MW, Q = 54.88 MVar
# Generator 67 at bus 295: P = 8.94 MW, Q = 8.94 MVar
#
# === Bus Voltages (p.u.) ===
# Bus 0: |V| = 1.0758 p.u., angle = 5.20°
# Bus 1: |V| = 1.0787 p.u., angle = 6.88°
# Bus 2: |V| = 1.0450 p.u., angle = 6.34°
# Bus 3: |V| = 1.0212 p.u., angle = 5.21°
# Bus 4: |V| = 1.0680 p.u., angle = 4.09°
# Bus 5: |V| = 1.0759 p.u., angle = 6.24°
# Bus 6: |V| = 1.0403 p.u., angle = 5.78°
# Bus 7: |V| = 1.0535 p.u., angle = 2.59°
# Bus 8: |V| = 1.0555 p.u., angle = 2.42°
# Bus 9: |V| = 1.0718 p.u., angle = 1.15°
# Bus 10: |V| = 1.0600 p.u., angle = 2.06°
# Bus 11: |V| = 1.0443 p.u., angle = 4.73°
# Bus 12: |V| = 1.0516 p.u., angle = -0.67°
# Bus 13: |V| = 1.0136 p.u., angle = -2.59°
# Bus 14: |V| = 1.0195 p.u., angle = -4.61°
# Bus 15: |V| = 1.0319 p.u., angle = 0.62°
# Bus 16: |V| = 1.0060 p.u., angle = -6.93°
# Bus 17: |V| = 1.0341 p.u., angle = 1.25°
# Bus 18: |V| = 1.0537 p.u., angle = -2.40°
# Bus 19: |V| = 1.0237 p.u., angle = 1.38°
# Bus 20: |V| = 1.0476 p.u., angle = -2.14°
# Bus 21: |V| = 1.0918 p.u., angle = 2.72°
# Bus 22: |V| = 1.0429 p.u., angle = 4.81°
# Bus 23: |V| = 1.0680 p.u., angle = 0.47°
# Bus 24: |V| = 1.0471 p.u., angle = -2.32°
# Bus 25: |V| = 1.0272 p.u., angle = -4.97°
# Bus 26: |V| = 1.0452 p.u., angle = -6.03°
# Bus 27: |V| = 1.0524 p.u., angle = -1.95°
# Bus 28: |V| = 1.0201 p.u., angle = -10.65°
# Bus 29: |V| = 1.0460 p.u., angle = -8.94°
# Bus 30: |V| = 1.0454 p.u., angle = -5.32°
# Bus 31: |V| = 1.0415 p.u., angle = -6.51°
# Bus 32: |V| = 1.0560 p.u., angle = 0.21°
# Bus 33: |V| = 1.0465 p.u., angle = -6.75°
# Bus 34: |V| = 1.0480 p.u., angle = -4.78°
# Bus 35: |V| = 1.0547 p.u., angle = -1.45°
# Bus 36: |V| = 1.0248 p.u., angle = -9.34°
# Bus 37: |V| = 1.0314 p.u., angle = -8.81°
# Bus 38: |V| = 1.0486 p.u., angle = -6.16°
# Bus 39: |V| = 1.0584 p.u., angle = -3.83°
# Bus 40: |V| = 1.0129 p.u., angle = -12.84°
# Bus 41: |V| = 1.0476 p.u., angle = -9.71°
# Bus 42: |V| = 1.0500 p.u., angle = -1.64°
# Bus 43: |V| = 1.0364 p.u., angle = -4.09°
# Bus 44: |V| = 1.0044 p.u., angle = -6.44°
# Bus 45: |V| = 1.0178 p.u., angle = -10.07°
# Bus 46: |V| = 1.0222 p.u., angle = -8.66°
# Bus 47: |V| = 1.0169 p.u., angle = -5.82°
# Bus 48: |V| = 1.0203 p.u., angle = -2.26°
# Bus 49: |V| = 0.9980 p.u., angle = -1.73°
# Bus 50: |V| = 0.9919 p.u., angle = -1.42°
# Bus 51: |V| = 1.0497 p.u., angle = -2.75°
# Bus 52: |V| = 1.0072 p.u., angle = 0.20°
# Bus 53: |V| = 1.0291 p.u., angle = 2.96°
# Bus 54: |V| = 0.9764 p.u., angle = -8.00°
# Bus 55: |V| = 0.9962 p.u., angle = -4.94°
# Bus 56: |V| = 1.0143 p.u., angle = -11.54°
# Bus 57: |V| = 0.9770 p.u., angle = -19.30°
# Bus 58: |V| = 1.0037 p.u., angle = -14.28°
# Bus 59: |V| = 1.0103 p.u., angle = -12.20°
# Bus 60: |V| = 1.0166 p.u., angle = -12.10°
# Bus 61: |V| = 1.0379 p.u., angle = -9.62°
# Bus 62: |V| = 1.0110 p.u., angle = -11.11°
# Bus 63: |V| = 1.0281 p.u., angle = -9.85°
# Bus 64: |V| = 1.0336 p.u., angle = -9.05°
# Bus 65: |V| = 1.0259 p.u., angle = -10.35°
# Bus 66: |V| = 1.0368 p.u., angle = -9.76°
# Bus 67: |V| = 1.0746 p.u., angle = -6.19°
# Bus 68: |V| = 1.0619 p.u., angle = -2.15°
# Bus 69: |V| = 1.0799 p.u., angle = -12.04°
# Bus 70: |V| = 1.0751 p.u., angle = -9.58°
# Bus 71: |V| = 1.0601 p.u., angle = -5.13°
# Bus 72: |V| = 1.0572 p.u., angle = -8.07°
# Bus 73: |V| = 1.0550 p.u., angle = -6.41°
# Bus 74: |V| = 1.0509 p.u., angle = -5.97°
# Bus 75: |V| = 1.0918 p.u., angle = -4.99°
# Bus 76: |V| = 1.0918 p.u., angle = -1.42°
# Bus 77: |V| = 1.0544 p.u., angle = -6.31°
# Bus 78: |V| = 1.0838 p.u., angle = -8.42°
# Bus 79: |V| = 1.0918 p.u., angle = -9.78°
# Bus 80: |V| = 1.0857 p.u., angle = -13.81°
# Bus 81: |V| = 1.0851 p.u., angle = -9.59°
# Bus 82: |V| = 1.0818 p.u., angle = -10.28°
# Bus 83: |V| = 1.0827 p.u., angle = -6.82°
# Bus 84: |V| = 1.0838 p.u., angle = -11.86°
# Bus 85: |V| = 1.0761 p.u., angle = -7.41°
# Bus 86: |V| = 1.0681 p.u., angle = -9.92°
# Bus 87: |V| = 1.0886 p.u., angle = -13.83°
# Bus 88: |V| = 1.0437 p.u., angle = -17.57°
# Bus 89: |V| = 1.0500 p.u., angle = -16.96°
# Bus 90: |V| = 1.0264 p.u., angle = -19.06°
# Bus 91: |V| = 1.0153 p.u., angle = -15.52°
# Bus 92: |V| = 1.0259 p.u., angle = -18.80°
# Bus 93: |V| = 0.9945 p.u., angle = -10.03°
# Bus 94: |V| = 1.0594 p.u., angle = -9.03°
# Bus 95: |V| = 0.9755 p.u., angle = -1.69°
# Bus 96: |V| = 0.9717 p.u., angle = -1.12°
# Bus 97: |V| = 1.0918 p.u., angle = 7.70°
# Bus 98: |V| = 1.0095 p.u., angle = -5.08°
# Bus 99: |V| = 1.0292 p.u., angle = -8.96°
# Bus 100: |V| = 1.0024 p.u., angle = -10.88°
# Bus 101: |V| = 1.0272 p.u., angle = -13.85°
# Bus 102: |V| = 1.0546 p.u., angle = -9.80°
# Bus 103: |V| = 1.0272 p.u., angle = -14.69°
# Bus 104: |V| = 1.0108 p.u., angle = -10.31°
# Bus 105: |V| = 1.0207 p.u., angle = -9.55°
# Bus 106: |V| = 1.0349 p.u., angle = -4.69°
# Bus 107: |V| = 1.0336 p.u., angle = -4.22°
# Bus 108: |V| = 1.0620 p.u., angle = 4.85°
# Bus 109: |V| = 1.0311 p.u., angle = 5.57°
# Bus 110: |V| = 1.0424 p.u., angle = 2.69°
# Bus 111: |V| = 1.0349 p.u., angle = -5.52°
# Bus 112: |V| = 1.0407 p.u., angle = -7.71°
# Bus 113: |V| = 1.0455 p.u., angle = -7.04°
# Bus 114: |V| = 1.0843 p.u., angle = -0.39°
# Bus 115: |V| = 1.0788 p.u., angle = -2.54°
# Bus 116: |V| = 1.0918 p.u., angle = -7.17°
# Bus 117: |V| = 1.0483 p.u., angle = -4.49°
# Bus 118: |V| = 1.0777 p.u., angle = -4.44°
# Bus 119: |V| = 1.0750 p.u., angle = -1.36°
# Bus 120: |V| = 1.0550 p.u., angle = -3.62°
# Bus 121: |V| = 1.0797 p.u., angle = 3.17°
# Bus 122: |V| = 1.0303 p.u., angle = 2.97°
# Bus 123: |V| = 1.0444 p.u., angle = -1.46°
# Bus 124: |V| = 1.0897 p.u., angle = 2.32°
# Bus 125: |V| = 1.0918 p.u., angle = 5.72°
# Bus 126: |V| = 1.0918 p.u., angle = -0.51°
# Bus 127: |V| = 1.0918 p.u., angle = 3.99°
# Bus 128: |V| = 1.0322 p.u., angle = 5.91°
# Bus 129: |V| = 1.0475 p.u., angle = 3.53°
# Bus 130: |V| = 1.0918 p.u., angle = 5.83°
# Bus 131: |V| = 1.0797 p.u., angle = 6.14°
# Bus 132: |V| = 1.0122 p.u., angle = -5.32°
# Bus 133: |V| = 1.0697 p.u., angle = 2.53°
# Bus 134: |V| = 1.0067 p.u., angle = 1.08°
# Bus 135: |V| = 1.0107 p.u., angle = -8.72°
# Bus 136: |V| = 1.0191 p.u., angle = -8.28°
# Bus 137: |V| = 1.0167 p.u., angle = -6.67°
# Bus 138: |V| = 1.0261 p.u., angle = -9.14°
# Bus 139: |V| = 1.0780 p.u., angle = 4.57°
# Bus 140: |V| = 1.0608 p.u., angle = 11.88°
# Bus 141: |V| = 1.0878 p.u., angle = 0.49°
# Bus 142: |V| = 1.0411 p.u., angle = 5.11°
# Bus 143: |V| = 1.0693 p.u., angle = 17.96°
# Bus 144: |V| = 1.0640 p.u., angle = 21.02°
# Bus 145: |V| = 1.0058 p.u., angle = -6.60°
# Bus 146: |V| = 1.0349 p.u., angle = -4.72°
# Bus 147: |V| = 1.0188 p.u., angle = -6.36°
# Bus 148: |V| = 0.9685 p.u., angle = -0.21°
# Bus 149: |V| = 1.0169 p.u., angle = -9.51°
# Bus 150: |V| = 1.0607 p.u., angle = -7.23°
# Bus 151: |V| = 1.0309 p.u., angle = -13.61°
# Bus 152: |V| = 1.0918 p.u., angle = -3.96°
# Bus 153: |V| = 1.0160 p.u., angle = -8.04°
# Bus 154: |V| = 1.0918 p.u., angle = 0.95°
# Bus 155: |V| = 1.0482 p.u., angle = -2.07°
# Bus 156: |V| = 0.9787 p.u., angle = -7.64°
# Bus 157: |V| = 1.0053 p.u., angle = -9.97°
# Bus 158: |V| = 1.0169 p.u., angle = -4.27°
# Bus 159: |V| = 1.0828 p.u., angle = -2.44°
# Bus 160: |V| = 1.0810 p.u., angle = -5.12°
# Bus 161: |V| = 1.0077 p.u., angle = 3.03°
# Bus 162: |V| = 1.0442 p.u., angle = -6.43°
# Bus 163: |V| = 1.0495 p.u., angle = -3.86°
# Bus 164: |V| = 1.0918 p.u., angle = 0.80°
# Bus 165: |V| = 1.0916 p.u., angle = 0.09°
# Bus 166: |V| = 1.0835 p.u., angle = -1.89°
# Bus 167: |V| = 1.0105 p.u., angle = -11.35°
# Bus 168: |V| = 1.0890 p.u., angle = -4.65°
# Bus 169: |V| = 1.0918 p.u., angle = 18.80°
# Bus 170: |V| = 1.0124 p.u., angle = -0.55°
# Bus 171: |V| = 1.0039 p.u., angle = -12.91°
# Bus 172: |V| = 1.0884 p.u., angle = -4.92°
# Bus 173: |V| = 1.0794 p.u., angle = -6.23°
# Bus 174: |V| = 1.0401 p.u., angle = -9.35°
# Bus 175: |V| = 1.0542 p.u., angle = -8.20°
# Bus 176: |V| = 1.0767 p.u., angle = -5.42°
# Bus 177: |V| = 1.0236 p.u., angle = -10.23°
# Bus 178: |V| = 1.0272 p.u., angle = -10.12°
# Bus 179: |V| = 0.9688 p.u., angle = -14.20°
# Bus 180: |V| = 1.0317 p.u., angle = -9.81°
# Bus 181: |V| = 1.0632 p.u., angle = -7.09°
# Bus 182: |V| = 0.9623 p.u., angle = -14.62°
# Bus 183: |V| = 0.9878 p.u., angle = -13.96°
# Bus 184: |V| = 1.0263 p.u., angle = -16.32°
# Bus 185: |V| = 1.0473 p.u., angle = -17.22°
# Bus 186: |V| = 1.0084 p.u., angle = -12.63°
# Bus 187: |V| = 1.0116 p.u., angle = -10.82°
# Bus 188: |V| = 1.0465 p.u., angle = -8.66°
# Bus 189: |V| = 1.0585 p.u., angle = -8.08°
# Bus 190: |V| = 1.0679 p.u., angle = -7.38°
# Bus 191: |V| = 1.0844 p.u., angle = 2.79°
# Bus 192: |V| = 1.0612 p.u., angle = -2.35°
# Bus 193: |V| = 1.0529 p.u., angle = -4.79°
# Bus 194: |V| = 1.0402 p.u., angle = -6.70°
# Bus 195: |V| = 1.0790 p.u., angle = -6.22°
# Bus 196: |V| = 1.0890 p.u., angle = -6.53°
# Bus 197: |V| = 1.0918 p.u., angle = -5.37°
# Bus 198: |V| = 1.0842 p.u., angle = -5.47°
# Bus 199: |V| = 1.0804 p.u., angle = -6.43°
# Bus 200: |V| = 1.0689 p.u., angle = -6.65°
# Bus 201: |V| = 1.0764 p.u., angle = -6.63°
# Bus 202: |V| = 1.0676 p.u., angle = -6.15°
# Bus 203: |V| = 1.0205 p.u., angle = -0.45°
# Bus 204: |V| = 1.0767 p.u., angle = -5.97°
# Bus 205: |V| = 1.0461 p.u., angle = -10.25°
# Bus 206: |V| = 1.0847 p.u., angle = -4.67°
# Bus 207: |V| = 1.0915 p.u., angle = -3.73°
# Bus 208: |V| = 1.0829 p.u., angle = 2.18°
# Bus 209: |V| = 1.0878 p.u., angle = -5.27°
# Bus 210: |V| = 1.0730 p.u., angle = -7.04°
# Bus 211: |V| = 1.0789 p.u., angle = -8.96°
# Bus 212: |V| = 1.0815 p.u., angle = -4.60°
# Bus 213: |V| = 1.0860 p.u., angle = -4.76°
# Bus 214: |V| = 1.0379 p.u., angle = 0.89°
# Bus 215: |V| = 1.0904 p.u., angle = -5.18°
# Bus 216: |V| = 1.0871 p.u., angle = -4.69°
# Bus 217: |V| = 1.0916 p.u., angle = -0.18°
# Bus 218: |V| = 1.0562 p.u., angle = -4.20°
# Bus 219: |V| = 1.0788 p.u., angle = -0.57°
# Bus 220: |V| = 1.0622 p.u., angle = -2.31°
# Bus 221: |V| = 1.0667 p.u., angle = -3.57°
# Bus 222: |V| = 1.0522 p.u., angle = -4.47°
# Bus 223: |V| = 1.0377 p.u., angle = -5.19°
# Bus 224: |V| = 1.0304 p.u., angle = -5.91°
# Bus 225: |V| = 1.0391 p.u., angle = -5.95°
# Bus 226: |V| = 1.0508 p.u., angle = -9.27°
# Bus 227: |V| = 1.0503 p.u., angle = -9.64°
# Bus 228: |V| = 1.0918 p.u., angle = -8.03°
# Bus 229: |V| = 1.0575 p.u., angle = -4.13°
# Bus 230: |V| = 1.0526 p.u., angle = 0.58°
# Bus 231: |V| = 1.0625 p.u., angle = -2.78°
# Bus 232: |V| = 1.0882 p.u., angle = -12.10°
# Bus 233: |V| = 1.0663 p.u., angle = -9.16°
# Bus 234: |V| = 1.0757 p.u., angle = -16.44°
# Bus 235: |V| = 0.9630 p.u., angle = -24.02°
# Bus 236: |V| = 0.9977 p.u., angle = -21.60°
# Bus 237: |V| = 1.0016 p.u., angle = -13.70°
# Bus 238: |V| = 1.0449 p.u., angle = -8.41°
# Bus 239: |V| = 1.0238 p.u., angle = -15.14°
# Bus 240: |V| = 1.0042 p.u., angle = -13.37°
# Bus 241: |V| = 1.0717 p.u., angle = -2.87°
# Bus 242: |V| = 1.0605 p.u., angle = 6.55°
# Bus 243: |V| = 1.0798 p.u., angle = -3.95°
# Bus 244: |V| = 1.0743 p.u., angle = -10.44°
# Bus 245: |V| = 1.0379 p.u., angle = -9.78°
# Bus 246: |V| = 1.0918 p.u., angle = 9.28°
# Bus 247: |V| = 1.0918 p.u., angle = 10.73°
# Bus 248: |V| = 1.0804 p.u., angle = 12.29°
# Bus 249: |V| = 1.0771 p.u., angle = 4.20°
# Bus 250: |V| = 1.0918 p.u., angle = 10.20°
# Bus 251: |V| = 1.0918 p.u., angle = -3.89°
# Bus 252: |V| = 1.0913 p.u., angle = 4.53°
# Bus 253: |V| = 1.0543 p.u., angle = 10.51°
# Bus 254: |V| = 1.0918 p.u., angle = 7.83°
# Bus 255: |V| = 1.0918 p.u., angle = -4.48°
# Bus 256: |V| = 1.0507 p.u., angle = 0.00°
# Bus 257: |V| = 1.0918 p.u., angle = -1.09°
# Bus 258: |V| = 1.0918 p.u., angle = 1.79°
# Bus 259: |V| = 1.0380 p.u., angle = 5.03°
# Bus 260: |V| = 1.0918 p.u., angle = 8.86°
# Bus 261: |V| = 1.0768 p.u., angle = -9.49°
# Bus 262: |V| = 1.0918 p.u., angle = 16.36°
# Bus 263: |V| = 1.0888 p.u., angle = 1.48°
# Bus 264: |V| = 1.0772 p.u., angle = 24.82°
# Bus 265: |V| = 1.0371 p.u., angle = -5.30°
# Bus 266: |V| = 1.0446 p.u., angle = 0.17°
# Bus 267: |V| = 1.0140 p.u., angle = -13.31°
# Bus 268: |V| = 1.0076 p.u., angle = -13.44°
# Bus 269: |V| = 1.0388 p.u., angle = -5.16°
# Bus 270: |V| = 1.0324 p.u., angle = -11.17°
# Bus 271: |V| = 1.0215 p.u., angle = -12.37°
# Bus 272: |V| = 1.0419 p.u., angle = -1.55°
# Bus 273: |V| = 1.0391 p.u., angle = -0.03°
# Bus 274: |V| = 1.0165 p.u., angle = -2.37°
# Bus 275: |V| = 1.0258 p.u., angle = -0.32°
# Bus 276: |V| = 1.0219 p.u., angle = -2.17°
# Bus 277: |V| = 1.0163 p.u., angle = -1.28°
# Bus 278: |V| = 1.0171 p.u., angle = -1.20°
# Bus 279: |V| = 0.9643 p.u., angle = -18.33°
# Bus 280: |V| = 0.9761 p.u., angle = -17.22°
# Bus 281: |V| = 0.9615 p.u., angle = -18.63°
# Bus 282: |V| = 1.0289 p.u., angle = -14.65°
# Bus 283: |V| = 0.9822 p.u., angle = -16.61°
# Bus 284: |V| = 0.9911 p.u., angle = -16.11°
# Bus 285: |V| = 0.9885 p.u., angle = -16.05°
# Bus 286: |V| = 0.9714 p.u., angle = -17.77°
# Bus 287: |V| = 0.9948 p.u., angle = -14.86°
# Bus 288: |V| = 0.9820 p.u., angle = -15.95°
# Bus 289: |V| = 0.9959 p.u., angle = -14.95°
# Bus 290: |V| = 1.0098 p.u., angle = -13.40°
# Bus 291: |V| = 1.0569 p.u., angle = -0.05°
# Bus 292: |V| = 1.0110 p.u., angle = -10.75°
# Bus 293: |V| = 1.0406 p.u., angle = 0.14°
# Bus 294: |V| = 1.0475 p.u., angle = -0.57°
# Bus 295: |V| = 1.0393 p.u., angle = -1.20°
# Bus 296: |V| = 1.0060 p.u., angle = -14.05°
# Bus 297: |V| = 1.0109 p.u., angle = -13.53°
# Bus 298: |V| = 1.0205 p.u., angle = -3.42°
# Bus 299: |V| = 1.0830 p.u., angle = -0.34°

# %%
net.res_cost
# Out:
# np.float64(720169.5718263261)

# %%
model.model.obj()
# Out:
# 1034006.4370166801

# %%
import inspect
import pandapower

print(inspect.getsource(pandapower.run.runopp))
# Out:
# def runopp(net, verbose=False, calculate_voltage_angles=True, check_connectivity=True,
#            suppress_warnings=True, switch_rx_ratio=2, delta=1e-10, init="flat", numba=True,
#            trafo3w_losses="hv", consider_line_temperature=False, **kwargs):
#     """
#         Runs the  pandapower Optimal Power Flow.
#         Flexibilities, constraints and cost parameters are defined in the pandapower element tables.
#
#         Flexibilities can be defined in net.sgen / net.gen /net.load / net.storage /net.ext_grid
#         net.sgen.controllable if a static generator is controllable. If False,
#         the active and reactive power are assigned as in a normal power flow. If True, the following
#         flexibilities apply:
#
#         - net.gen.min_p_mw / net.gen.max_p_mw
#         - net.gen.min_q_mvar / net.gen.max_q_mvar
#         - net.sgen.min_p_mw / net.sgen.max_p_mw
#         - net.sgen.min_q_mvar / net.sgen.max_q_mvar
#         - net.dcline.max_p_mw
#         - net.dcline.min_q_to_mvar / net.dcline.max_q_to_mvar / net.dcline.min_q_from_mvar / net.dcline.max_q_from_mvar
#         - net.ext_grid.min_p_mw / net.ext_grid.max_p_mw
#         - net.ext_grid.min_q_mvar / net.ext_grid.max_q_mvar
#         - net.load.min_p_mw / net.load.max_p_mw
#         - net.load.min_q_mvar / net.load.max_q_mvar
#         - net.storage.min_p_mw / net.storage.max_p_mw
#         - net.storage.min_q_mvar / net.storage.max_q_mvar
#
#         Controllable loads behave just like controllable static generators. It must be stated if they are controllable.
#         Otherwise, they are not respected as flexibilities.
#         Dc lines are controllable per default
#
#         Network constraints can be defined for buses, lines and transformers the elements in the following columns:
#
#         - net.bus.min_vm_pu / net.bus.max_vm_pu
#         - net.line.max_loading_percent
#         - net.trafo.max_loading_percent
#         - net.trafo3w.max_loading_percent
#
#         If the external grid ist controllable, the voltage setpoint of the external grid can be optimized within the
#         voltage constraints by the OPF. The same applies to the voltage setpoints of the controllable generator elements.
#
#         How these costs are combined into a cost function depends on the cost_function parameter.
#
#         INPUT:
#             **net** - The pandapower format network
#
#         OPTIONAL:
#             **verbose** (bool, False) - If True, some basic information is printed
#
#             **suppress_warnings** (bool, True) - suppress warnings in pypower
#
#                 If set to True, warnings are disabled during the loadflow. Because of the way data is
#                 processed in pypower, ComplexWarnings are raised during the loadflow.
#                 These warnings are suppressed by this option, however keep in mind all other pypower
#                 warnings are suppressed, too.
#
#             **init** (str, "flat") - init of starting opf vector. Options are "flat", "pf" or "results"
#
#                 Starting solution vector (x0) for opf calculations is determined by this flag. Options are:
#                 "flat" (default): starting vector is (upper bound - lower bound) / 2
#                 "pf": a power flow is executed prior to the opf and the pf solution is the starting vector. This may improve
#                 convergence, but takes a longer runtime (which are probably neglectible for opf calculations)
#                 "results": voltage magnitude vector is taken from result table
#
#             **delta** (float, 1e-10) - power tolerance
#
#             **trafo3w_losses** (str, "hv") - defines where open loop losses of three-winding transformers are considered. Valid options are "hv", "mv", "lv" for HV/MV/LV side or "star" for the star point.
#
#             **consider_line_temperature** (bool, False) - adjustment of line impedance based on provided\
#                 line temperature. If True, net.line must contain a column "temperature_degree_celsius".\
#                 The temperature dependency coefficient alpha must be provided in the net.line.alpha\
#                 column, otherwise the default value of 0.004 is used
#
#             **kwargs** - Pypower / Matpower keyword arguments:
#
#             - OPF_VIOLATION (5e-6) constraint violation tolerance
#             - PDIPM_COSTTOL (1e-6) optimality tolerance
#             - PDIPM_GRADTOL (1e-6) gradient tolerance
#             - PDIPM_COMPTOL (1e-6) complementarity condition (inequality) tolerance
#             - PDIPM_FEASTOL (set to OPF_VIOLATION if not specified) feasibiliy (equality) tolerance
#             - PDIPM_MAX_IT  (150) maximum number of iterations
#             - SCPDIPM_RED_IT(20) maximum number of step size reductions per iteration
#     """
#     _check_necessary_opf_parameters(net, logger)
#     _init_runopp_options(net, calculate_voltage_angles=calculate_voltage_angles,
#                          check_connectivity=check_connectivity,
#                          switch_rx_ratio=switch_rx_ratio, delta=delta, init=init, numba=numba,
#                          trafo3w_losses=trafo3w_losses,
#                          consider_line_temperature=consider_line_temperature, **kwargs)
#     _check_bus_index_and_print_warning_if_high(net)
#     _check_gen_index_and_print_warning_if_high(net)
#     _optimal_powerflow(net, verbose, suppress_warnings, **kwargs)

# %%
import pandapower.optimal_powerflow
print(inspect.getsource(pandapower.optimal_powerflow._optimal_powerflow))
# Out:
# def _optimal_powerflow(net, verbose, suppress_warnings, **kwargs):
#     ac = net["_options"]["ac"]
#     init = net["_options"]["init"]
#
#     if "OPF_FLOW_LIM" not in kwargs:
#         kwargs["OPF_FLOW_LIM"] = 2
#
#     if net["_options"]["voltage_depend_loads"] and not (
#             allclose(net.load.const_z_percent.values, 0) and
#             allclose(net.load.const_i_percent.values, 0)):
#         logger.error("pandapower optimal_powerflow does not support voltage depend loads.")
#
#     ppopt = ppoption(VERBOSE=verbose, PF_DC=not ac, INIT=init, **kwargs)
#     net["OPF_converged"] = False
#     net["converged"] = False
#     _add_auxiliary_elements(net)
#
#     if not ac or net["_options"]["init_results"]:
#         verify_results(net)
#     else:
#         init_results(net, "opf")
#
#     ppc, ppci = _pd2ppc(net)
#
#     if not ac:
#         ppci["bus"][:, VM] = 1.0
#     net["_ppc_opf"] = ppci
#     if len(net.dcline) > 0:
#         ppci = add_userfcn(ppci, 'formulation', _add_dcline_constraints, args=net)
#
#     if init == "pf":
#         ppci = _run_pf_before_opf(net, ppci)
#     if suppress_warnings:
#         with warnings.catch_warnings():
#             warnings.simplefilter("ignore")
#             result = opf(ppci, ppopt)
#     else:
#         result = opf(ppci, ppopt)
# #    net["_ppc_opf"] = result
#
#     if verbose:
#         ppopt['OUT_ALL'] = 1
#         printpf(baseMVA=result["baseMVA"], bus=result["bus"], gen=result["gen"],
#                 branch=result["branch"],  f=result["f"],  success=result["success"],
#                 et=result["et"], fd=stdout, ppopt=ppopt)
#
#     if not result["success"]:
#         raise OPFNotConverged("Optimal Power Flow did not converge!")
#
#     # ppci doesn't contain out of service elements, but ppc does -> copy results accordingly
#     mode = net["_options"]["mode"]
#     result = _copy_results_ppci_to_ppc(result, ppc, mode=mode)
#
# #    net["_ppc_opf"] = result
#     net["OPF_converged"] = True
#     _extract_results(net, result)
#     _clean_up(net)
